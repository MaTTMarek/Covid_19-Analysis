# %%
# import libraries
import pandas as pd
import numpy as np
import os

# %%
# import data set
df=pd.read_csv(r'C:\Users\mateu\Desktop\CF\6.0\archive\owid-covid-data.csv')

# %%
# path
path = r'C:\Users\mateu\Desktop\CF\Master_Folder'

# %%
# data check
pd.options.display.max_columns = None
df.head(1000)
# Out:
#      iso_code continent     location        date  total_cases  new_cases  \
# 0         AFG      Asia  Afghanistan  2020-02-24          5.0        5.0
# 1         AFG      Asia  Afghanistan  2020-02-25          5.0        0.0
# 2         AFG      Asia  Afghanistan  2020-02-26          5.0        0.0
# 3         AFG      Asia  Afghanistan  2020-02-27          5.0        0.0
# 4         AFG      Asia  Afghanistan  2020-02-28          5.0        0.0
# ..        ...       ...          ...         ...          ...        ...
# 995  OWID_AFR       NaN       Africa  2020-10-24    1709369.0    11761.0
# 996  OWID_AFR       NaN       Africa  2020-10-25    1718465.0     9096.0
# 997  OWID_AFR       NaN       Africa  2020-10-26    1729156.0    10691.0
# 998  OWID_AFR       NaN       Africa  2020-10-27    1737828.0     8672.0
# 999  OWID_AFR       NaN       Africa  2020-10-28    1749731.0    11903.0
#
#      new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  \
# ...

# %%
# data check
df.shape
# Out:
# (166326, 67)

# %%
# data check
pd.set_option('display.max_rows', None)
df.dtypes
# Out:
# iso_code                                       object
# continent                                      object
# location                                       object
# date                                           object
# total_cases                                   float64
# new_cases                                     float64
# new_cases_smoothed                            float64
# total_deaths                                  float64
# new_deaths                                    float64
# new_deaths_smoothed                           float64
# total_cases_per_million                       float64
# new_cases_per_million                         float64
# new_cases_smoothed_per_million                float64
# total_deaths_per_million                      float64
# new_deaths_per_million                        float64
# new_deaths_smoothed_per_million               float64
# reproduction_rate                             float64
# ...

# %%
# I will change only iso_code to Country_Code,rest looks fine to me
df1.rename(columns= {'iso_code':'Country_Code'},axis=1,)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_12708/3911573108.py in <module>
#       1 # I will change only iso_code to Country_Code,rest looks fine to me
# ----> 2 df1.rename(columns= {'iso_code':'Country_Code'},axis=1,)
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     322         @wraps(func)
#     323         def wrapper(*args, **kwargs) -> Callable[..., Any]:
# --> 324             return func(*args, **kwargs)
#     325
#     326         kind = inspect.Parameter.POSITIONAL_OR_KEYWORD
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in rename(self, mapper, index, columns, axis, copy, inplace, level, errors)
#    5037         4  3  6
#    5038         """
# -> 5039         return super().rename(
#    5040             mapper=mapper,
#    5041             index=index,
#
# ...

# %%
# check
df1.head()
# Out:
#   Country_Code continent     location        date  total_cases  new_cases  \
# 0          AFG      Asia  Afghanistan  2020-02-24          5.0        5.0
# 1          AFG      Asia  Afghanistan  2020-02-25          5.0        0.0
# 2          AFG      Asia  Afghanistan  2020-02-26          5.0        0.0
# 3          AFG      Asia  Afghanistan  2020-02-27          5.0        0.0
# 4          AFG      Asia  Afghanistan  2020-02-28          5.0        0.0
#
#    new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  \
# 0                 NaN           NaN         NaN                  NaN
# 1                 NaN           NaN         NaN                  NaN
# 2                 NaN           NaN         NaN                  NaN
# 3                 NaN           NaN         NaN                  NaN
# 4                 NaN           NaN         NaN                  NaN
#
#    total_cases_per_million  new_cases_per_million  total_deaths_per_million  \
# ...

# %%
# checking fo duplicates
df1[df1.duplicated()]
# Out:
# Empty DataFrame
# ...

# %% [markdown]
# ### no issues here

# %%
# looking for mixed data types

for col in df1.columns.tolist():
  weird = (df1[[col]].applymap(type) != df1[[col]].iloc[0].apply(type)).any(axis = 1)
  if len (df1[weird]) > 0:
    print (col)
# Out:
# continent

# %%
# changing data type
df1 = df.astype({'continent': str})

# %%
# check
for col in df1.columns.tolist():
  weird = (df1[[col]].applymap(type) != df1[[col]].iloc[0].apply(type)).any(axis = 1)
  if len (df1[weird]) > 0:
    print (col)
# Out:
# tests_units

# %%
# changing data type
df1 = df.astype({'tests_units': str,})

# %%
# check
for col in df1.columns.tolist():
  weird = (df1[[col]].applymap(type) != df1[[col]].iloc[0].apply(type)).any(axis = 1)
  if len (df1[weird]) > 0:
    print (col)

# %% [markdown]
# ### Closer look to missing values

# %%
# lokking for missng values
pd.set_option('display.max_rows', None)
df1.isnull().sum()
# Out:
# iso_code                                           0
# continent                                          0
# location                                           0
# date                                               0
# total_cases                                     3033
# new_cases                                       3193
# new_cases_smoothed                              5176
# total_deaths                                   20875
# new_deaths                                     20839
# new_deaths_smoothed                            22936
# total_cases_per_million                         3791
# new_cases_per_million                           3951
# new_cases_smoothed_per_million                  5928
# total_deaths_per_million                       21620
# new_deaths_per_million                         21584
# new_deaths_smoothed_per_million                23675
# reproduction_rate                              40506
# icu_patients                                  142863
# ...

# %%
# droping columns
df_drop=df.drop(['icu_patients','hosp_patients','hosp_patients_per_million','weekly_icu_admissions','weekly_hosp_admissions',
             'weekly_hosp_admissions_per_million','new_tests','total_tests','total_tests_per_thousand','new_tests_smoothed_per_thousand',
             'total_boosters_per_hundred','excess_mortality_cumulative_per_million','new_cases_smoothed_per_million','new_people_vaccinated_smoothed_per_hundred',
             'new_deaths_smoothed_per_million','extreme_poverty',
             'icu_patients_per_million','new_tests_smoothed','tests_units',
'new_vaccinations_smoothed','excess_mortality_cumulative_absolute','excess_mortality_cumulative',
             'excess_mortality','weekly_icu_admissions_per_million'],axis=1)

# %%
# checking
df_drop.shape
# Out:
# (166326, 43)

# %%
# checking
pd.set_option('display.max_rows', None)
df_drop.isnull().sum()
# Out:
# iso_code                                      0
# continent                                     0
# location                                      0
# date                                          0
# total_cases                                3033
# new_cases                                  3193
# new_cases_smoothed                         5176
# total_deaths                              20875
# new_deaths                                20839
# new_deaths_smoothed                       22936
# total_cases_per_million                    3791
# new_cases_per_million                      3951
# total_deaths_per_million                  21620
# new_deaths_per_million                    21584
# reproduction_rate                         40506
# new_tests_per_thousand                    99009
# positive_rate                             87671
# tests_per_case                            88242
# total_vaccinations                       121132
# people_vaccinated                        123339
# ...

# %%
# replacing missing values with 0. I don't want to remove this columns because I might need data for specific countries only

# %%
df_drop['new_tests_per_thousand'] = df_drop['new_tests_per_thousand'].fillna(0)

# %%
df_drop['positive_rate'] = df_drop['positive_rate'].fillna(0)

# %%
df_drop['tests_per_case'] = df_drop['tests_per_case'].fillna(0)

# %%
df_drop['total_vaccinations'] = df_drop['total_vaccinations'].fillna(0)

# %%
df_drop['people_vaccinated'] = df_drop['people_vaccinated'].fillna(0)

# %%
df_drop['people_fully_vaccinated'] = df_drop['people_fully_vaccinated'].fillna(0)

# %%
df_drop['total_boosters'] = df_drop['total_boosters'].fillna(0)

# %%
df_drop['new_vaccinations'] = df_drop['new_vaccinations'].fillna(0)

# %%
df_drop['total_vaccinations_per_hundred'] = df_drop['total_vaccinations_per_hundred'].fillna(0)

# %%
df_drop['people_vaccinated_per_hundred'] = df_drop['people_vaccinated_per_hundred'].fillna(0)

# %%
df_drop['people_fully_vaccinated_per_hundred'] = df_drop['people_fully_vaccinated_per_hundred'].fillna(0)

# %%
df_drop['new_vaccinations_smoothed_per_million'] = df_drop['new_vaccinations_smoothed_per_million'].fillna(0)

# %%
df_drop['new_people_vaccinated_smoothed'] = df_drop['new_people_vaccinated_smoothed'].fillna(0)

# %%
df_drop['new_tests_per_thousand'] = df_drop['new_tests_per_thousand'].fillna(0)

# %%
df_drop.isnull().sum()
# Out:
# iso_code                                     0
# continent                                    0
# location                                     0
# date                                         0
# total_cases                               3033
# new_cases                                 3193
# new_cases_smoothed                        5176
# total_deaths                             20875
# new_deaths                               20839
# new_deaths_smoothed                      22936
# total_cases_per_million                   3791
# new_cases_per_million                     3951
# total_deaths_per_million                 21620
# new_deaths_per_million                   21584
# reproduction_rate                        40506
# new_tests_per_thousand                       0
# positive_rate                                0
# tests_per_case                               0
# total_vaccinations                           0
# people_vaccinated                            0
# ...

# %%
# filling values with the mean
df_drop.fillna(df.mean(), inplace=True)
# Out:
# C:\Users\mateu\AppData\Local\Temp/ipykernel_5200/872063871.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df_drop.fillna(df.mean(), inplace=True)

# %%
# checking
df_drop.isnull().sum()
# Out:
# iso_code                                 0
# continent                                0
# location                                 0
# date                                     0
# total_cases                              0
# new_cases                                0
# new_cases_smoothed                       0
# total_deaths                             0
# new_deaths                               0
# new_deaths_smoothed                      0
# total_cases_per_million                  0
# new_cases_per_million                    0
# total_deaths_per_million                 0
# new_deaths_per_million                   0
# reproduction_rate                        0
# new_tests_per_thousand                   0
# positive_rate                            0
# tests_per_case                           0
# total_vaccinations                       0
# people_vaccinated                        0
# people_fully_vaccinated                  0
# total_boosters                           0
# ...

# %%
df_drop.to_csv(os.path.join(path, 'Covid_19'))
